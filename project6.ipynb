# %% [markdown]
# #### MongoDB Code Lab

# %%
# %env HOST=mongodb+srv://cluster0.a9rcadc.mongodb.net/sample_weatherdata
# %env USER=dsgirl826
# %env PW=mystery
# Out:
# env: HOST=mongodb+srv://cluster0.a9rcadc.mongodb.net/sample_weatherdata
# env: USER=dsgirl826
# env: PW=mystery

# %%
CONNECT="/usr/bin/mongosh $HOST -u $USER -p $PW --quiet"

# %%
# !{CONNECT}
# Out:
#  Atlas atlas-wtq44c-shard-0 [primary] sample_weatherdata>
# (To exit, press Ctrl+C again or Ctrl+D or type .exit)
# Atlas atlas-wtq44c-shard-0 [primary] sample_weatherdata>

# %%
# !{CONNECT} --eval "show collections" # shows collections in database
# Out:
#  data
# weather_data

# %%
# !{CONNECT} --eval "db.data.findOne()" # gets one document as a test
# Out:
#  {
#   _id: ObjectId("5553a998e4b02cf7151190cb"),
#   st: 'x+43400-065600',
#   ts: ISODate("1984-03-05T18:00:00.000Z"),
#   position: { type: 'Point', coordinates: [ -65.6, 43.4 ] },
#   elevation: 9999,
#   callLetters: 'CG26',
#   qualityControlProcess: 'V020',
#   dataSource: '4',
#   type: 'FM-13',
#   airTemperature: { value: 999.9, quality: '9' },
#   dewPoint: { value: 999.9, quality: '9' },
#   pressure: { value: 9999.9, quality: '9' },
#   wind: {
#     direction: { angle: 270, quality: '1' },
#     type: 'N',
#     speed: { rate: 7.7, quality: '1' }
#   },
#   visibility: {
#     distance: { value: 10000, quality: '1' },
#     variability: { value: 'N', quality: '9' }
#   },
#   skyCondition: {
#     ceilingHeight: { value: 22000, quality: '1', determination: 'C' },
#     cavok: 'N'
#   },
#   sections: [ 'AG1', 'AY1', 'GF1', 'MW1' ],
#   precipitationEstimatedObservation: { discrepancy: '2', estimatedWaterDepth: 0 },
#   pastWeatherObservationManual: [
#     {
# ...

# %%
#### begin project 6 work

# %%
# !{CONNECT} -f /home/jupyter/6mongodb/project6_queries.js
# Out:
#  ****************************************************************
# 1) Finds 10 documents with air temperature values between 4 and 5 exclusive, projecting _id, and airTemperature.values sorted by air temperature ascending
# [
#   {
#     _id: ObjectId("5553a999e4b02cf71511b821"),
#     airTemperature: {
#       value: 4.1
#     }
#   },
#   {
#     _id: ObjectId("5553a999e4b02cf71511bcd2"),
#     airTemperature: {
#       value: 4.1
#     }
#   },
#   {
#     _id: ObjectId("5553a999e4b02cf71511bf92"),
#     airTemperature: {
#       value: 4.1
#     }
#   },
#   {
#     _id: ObjectId("5553a998e4b02cf715119f62"),
#     airTemperature: {
#       value: 4.1
#     }
#   },
#   {
#     _id: ObjectId("5553a999e4b02cf71511bae0"),
#     airTemperature: {
#       value: 4.1
#     }
#   },
#   {
#     _id: ObjectId("5553a999e4b02cf71511bf88"),
#     airTemperature: {
#       value: 4.1
#     }
#   },
#   {
#     _id: ObjectId("5553a999e4b02cf71511bf20"),
#     airTemperature: {
# ...

# %%
# !{CONNECT} -f /home/jupyter/6mongodb/exam1_extra_credit.js
# Out:
#  ****************************************************************
# 1) Insert a single weather document with many fields
# {
#   acknowledged: true,
#   insertedId: ObjectId("653b155c987518d8557a95f9")
# }
# ****************************************************************
# 2) Insert two weather documents with five fields
# {
#   acknowledged: true,
#   insertedIds: {
#     '0': ObjectId("653b155c987518d8557a95fa"),
#     '1': ObjectId("653b155c987518d8557a95fb")
#   }
# }
# ****************************************************************
# 3) Insert two more weather documents with five fields
# {
#   acknowledged: true,
#   insertedIds: {
#     '0': ObjectId("653b155c987518d8557a95fc"),
#     '1': ObjectId("653b155c987518d8557a95fd")
#   }
# }
# ****************************************************************
# 4) Match the many fields document with the st field and change the elevation to 6000
# {
#   acknowledged: true,
#   insertedId: null,
#   matchedCount: 1,
# ...
